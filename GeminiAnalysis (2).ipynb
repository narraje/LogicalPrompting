# %%
import pandas as pd
import matplotlib.pyplot as plt

gemini_file_path = '/content/GeminiiFinal.xlsx'
gemini_data = pd.ExcelFile(gemini_file_path)

gemini_sheet1_data = gemini_data.parse('Sheet1')

average_scores = gemini_sheet1_data[['Accuracy', 'Completeness', 'Logical Soundess',
                                     'ACL2s Adherence', 'Efficiency', 'Hallucinations']].mean()

print(average_scores)
gemini_sheet1_data['Aggregate Score'] = gemini_sheet1_data[['Accuracy', 'Completeness', 'Logical Soundess',
                                                            'ACL2s Adherence', 'Efficiency', 'Hallucinations']].mean(axis=1)
gemini_sheet1_data['Rounded Aggregate Score'] = gemini_sheet1_data['Aggregate Score'].round()

plt.figure(figsize=(10, 6))
average_scores.plot(kind='bar', rot=45)
plt.title('Average Scores Across Criteria (Gemini Results)')
plt.ylabel('Average Score')
plt.xlabel('Criteria')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
gemini_sheet1_data['Rounded Aggregate Score'].value_counts().sort_index().plot(kind='bar', rot=0)
plt.title('Rounded Aggregate Score Distribution (Gemini Results)')
plt.xlabel('Rounded Aggregate Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

gemini_sheet2_data = gemini_data.parse('Sheet2')

average_scores = gemini_sheet2_data[['Accuracy', 'Completeness', 'Logical Soundess',
                                     'ACL2s Adherence', 'Efficiency', 'Hallucinations']].mean()

print(average_scores)
gemini_sheet2_data['Aggregate Score'] = gemini_sheet2_data[['Accuracy', 'Completeness', 'Logical Soundess',
                                                            'ACL2s Adherence', 'Efficiency', 'Hallucinations']].mean(axis=1)
gemini_sheet2_data['Rounded Aggregate Score'] = gemini_sheet2_data['Aggregate Score'].round()

plt.figure(figsize=(10, 6))
average_scores.plot(kind='bar', rot=45)
plt.title('Average Scores Across Criteria (Gemini Results)')
plt.ylabel('Average Score')
plt.xlabel('Criteria')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
gemini_sheet2_data['Rounded Aggregate Score'].value_counts().sort_index().plot(kind='bar', rot=0)
plt.title('Rounded Aggregate Score Distribution (Gemini Results)')
plt.xlabel('Rounded Aggregate Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

gemini_sheet3_data = gemini_data.parse('Sheet3')

average_scores = gemini_sheet3_data[['Accuracy', 'Completeness', 'Logical Soundess',
                                     'ACL2s Adherence', 'Efficiency', 'Hallucinations']].mean()

print(average_scores)
gemini_sheet3_data['Aggregate Score'] = gemini_sheet3_data[['Accuracy', 'Completeness', 'Logical Soundess',
                                                            'ACL2s Adherence', 'Efficiency', 'Hallucinations']].mean(axis=1)
gemini_sheet3_data['Rounded Aggregate Score'] = gemini_sheet3_data['Aggregate Score'].round()

plt.figure(figsize=(10, 6))
average_scores.plot(kind='bar', rot=45)
plt.title('Average Scores Across Criteria (Gemini Results)')
plt.ylabel('Average Score')
plt.xlabel('Criteria')
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
gemini_sheet3_data['Rounded Aggregate Score'].value_counts().sort_index().plot(kind='bar', rot=0)
plt.title('Rounded Aggregate Score Distribution (Gemini Results)')
plt.xlabel('Rounded Aggregate Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Accuracy            2.641509
# Completeness        3.415094
# Logical Soundess    2.600000
# ACL2s Adherence     1.735849
# Efficiency          3.433962
# Hallucinations      3.471698
# dtype: float64
# Accuracy            2.603774
# Completeness        3.000000
# Logical Soundess    1.533333
# ACL2s Adherence     2.113208
# Efficiency          2.716981
# Hallucinations      3.037736
# dtype: float64
# Accuracy            3.545455
# Completeness        4.000000
# Logical Soundess    2.818182
# ACL2s Adherence     2.909091
# Efficiency          3.454545
# Hallucinations      3.909091
# dtype: float64
