# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Model": ["ChatGPT", "Gemini", "CoPilot"],
    "Accuracy": [3.320755, 2.641509, 3.185714],
    "Completeness": [4.000000, 3.415094, 3.385714],
    "Logical Soundness": [2.800000,  2.600000, 3.242857],
    "ACL2s Adherence": [2.384615, 1.735849, 2.971429],
    "Efficiency": [3.415094, 3.433962, 3.100000],
    "Hallucinations": [3.773585, 3.471698, 3.200000]
}

cross_model_data = pd.DataFrame(data)
cross_model_data.set_index("Model", inplace=True)

# Plotting a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(cross_model_data, annot=True, cmap="coolwarm", cbar=True, fmt=".2f", linewidths= .5, vmin=0, vmax=5)
plt.title("Performance Heatmap: Collective Prompting")
plt.ylabel("Model")
plt.xlabel("Criteria")
plt.tight_layout()
plt.show()

data1 = {
    "Model": ["ChatGPT", "Gemini"],
    "Accuracy": [3.452830, 2.603774],
    "Completeness": [3.886792, 3.000000],
    "Logical Soundness": [2.866667,  1.533333],
    "ACL2s Adherence": [3.320755,  2.113208],
    "Efficiency": [2.792453, 2.716981],
    "Hallucinations": [3.566038, 3.037736]
}

cross_model_data1 = pd.DataFrame(data1)
cross_model_data1.set_index("Model", inplace=True)

# Plotting a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(cross_model_data1, annot=True, cmap="coolwarm", cbar=True, fmt=".2f", linewidths= .5, vmin=0, vmax=5)
plt.title("Performance Heatmap: Lecture Notes")
plt.ylabel("Model")
plt.xlabel("Criteria")
plt.tight_layout()
plt.show()

data2 = {
    "Model": ["ChatGPT", "CoPilot"],
    "Accuracy": [2.981132, 3.342857143],
    "Completeness": [3.358491, 3.385714286],
    "Logical Soundness": [2.333333, 3.385714286],
    "ACL2s Adherence": [2.622642, 2.614285714],
    "Efficiency": [3.169811, 3.214285714],
    "Hallucinations": [3.339623, 3.314285714]
}

cross_model_data2 = pd.DataFrame(data2)
cross_model_data2.set_index("Model", inplace=True)

# Plotting a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(cross_model_data2, annot=True, cmap="coolwarm", cbar=True, fmt=".2f", linewidths= .5, vmin=0, vmax=5)
plt.title("Performance Heatmap: Collective Prompting")
plt.ylabel("Model")
plt.xlabel("Criteria")
plt.tight_layout()
plt.show()

data3 = {
    "Model": ["ChatGPT", "Gemini", "CoPilot"],
    "Accuracy": [3.000000, 3.545455, 3.620689655],
    "Completeness": [4.222222, 4.000000, 3.586206897],
    "Logical Soundness": [2.500000,  2.818182, 3.620689655],
    "ACL2s Adherence": [3.833333, 2.909091, 3],
    "Efficiency": [2.722222, 3.454545, 3.379310345],
    "Hallucinations": [3.944444, 3.909091, 3.413793103]
}

cross_model_data3 = pd.DataFrame(data3)
cross_model_data3.set_index("Model", inplace=True)

# Plotting a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(cross_model_data3, annot=True, cmap="coolwarm", cbar=True, fmt=".2f", linewidths= .5, vmin=0, vmax=5)
plt.title("Performance Heatmap: Extended Prompting")
plt.ylabel("Model")
plt.xlabel("Criteria")
plt.tight_layout()
plt.show()
